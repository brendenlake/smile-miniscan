# %%
import sys
sys.path.insert(0, 'analysis/lib')
import json
# %pip install -e analysis
from smiledata import load_json
from smiledata.loader import load_latest

# %%
data = load_latest("data/anonymized")
participants_df = data.to_participants_df()
participants_df
# trials_df = data.to_trials_df()
# trials_df

# %%
DATA_PATH = "data/anonymized/testing-complete_only-main-data.json"
with open(DATA_PATH, 'r') as f:
  raw_data = json.load(f)
test_id = 'eyt2QRAiZD5mbFFKKB2k'
for p in raw_data:
  if p['id'] == test_id:
     mypart = p['data']
     break

# %%
mypart
# Out:
# {'appStartTime': 1777300103741,
#  'seedID': 'd2b0f15d-1e40-46e3-9704-f67dcf65eab7',
#  'firebaseAnonAuthID': 'WG6Ljcx2BZOqWHga42yLiqwmz4m1',
#  'trialNum': 0,
#  'consented': True,
#  'starttime': {'_seconds': 1777300107, '_nanoseconds': 245000000},
#  'starttimeLocal': '2026-04-27T10:28:27.245-04:00',
#  'userTimezone': 'America/New_York',
#  'userTimezoneOffset': 240,
#  'panda_id': None,
#  'recruitmentService': 'prolific',
#  'withdrawn': False,
#  'conditions': {},
#  'randomizedRoutes': {},
#  'smileConfig': {'mode': 'development',
#   'smileVersion': '0.1.0',
#   'projectName': 'smile-miniscan',
#   'projectRef': 'brendenlake-smile-miniscan-main',
#   'codeName': 'battle-rampant-cold',
#   'codeNameURL': 'http://localhost:3020/e/battle-rampant-cold',
#   'localStorageKey': 'smilestore-battle-rampant-cold',
#   'devLocalStorageKey': 'smilestore-battle-rampant-cold_dev',
#   'github': {'repoName': 'smile-miniscan',
#    'owner': 'brendenlake',
#    'branch': 'main',
#    'lastCommitMsg': 'Refactor: Remove deprecated HTML templates and update ScanExpView logic',
#    'lastCommitHash': '7380bd3',
#    'commitURL': 'https://github.com/brendenlake/smile-miniscan/commit/7380bd3'},
#   'allowRepeats': False,
#   'autoSave': True,
#   'maxWrites': 1000,
#   'minWriteInterval': 2000,
#   'maxSteps': '5000',
#   'randomSeed': '100012',
#   'deployURL': 'http://localhost:3020/brendenlake/smile-miniscan/main/',
#   'labURL': 'https://lake-lab.github.io/',
#   'brandLogoFn': 'universitylogo.png',
#   'colorMode': 'light',
#   'responsiveUI': True,
#   'googleAnalyticsID': '',
#   'windowsizerRequest': {'width': 800, 'height': 600},
#   'windowsizerAggressive': True,
#   'anonymousMode': False,
#   'firebaseConfig': {'apiKey': 'AIzaSyBRhVlQ_JdJzQn1urCegMptwDdyBfUzHwQ',
#    'authDomain': 'smile-miniscan.firebaseapp.com',
#    'projectId': 'smile-miniscan',
#    'storageBucket': 'smile-miniscan.firebasestorage.app',
#    'messagingSenderId': '43690389352',
#    'appId': '1:43690389352:web:33b84ce7191c1071bdf0dd'},
#   'runtime': {'estimated_time': '40 minutes', 'payrate': '$4 base payment'}},
#  'studyData': [],
#  'firebaseDocID': '',
#  'verifiedVisibility': True,
#  'pageData_quiz': {'visit_0': {'data': [{'phase': 'instructionsQuiz',
#      'questions': [{'id': 'pg1',
#        'questions': [{'id': 'q1',
#          'question': 'Each command is a series of:',
#          'multiSelect': False,
#          'answers': ['English words', 'Nonsense words', 'Colored circles'],
#          'correctAnswer': ['Nonsense words'],
#          'answer': 'Nonsense words'},
#         {'id': 'q2',
#          'question': 'The output for a command is a series of:',
#          'multiSelect': False,
#          'answers': ['English words', 'Nonsense words', 'Colored circles'],
#          'correctAnswer': ['Colored circles'],
#          'answer': 'Colored circles'},
#         {'id': 'q3',
#          'question': 'In the study phases, your task is to:',
#          'multiSelect': False,
#          'answers': ['Reproduce the output for each command.',
#           'Click on each command to reveal its output.',
#           'Count the number of unique commands.'],
#          'correctAnswer': ['Reproduce the output for each command.'],
#          'answer': 'Reproduce the output for each command.'},
#         {'id': 'q4',
#          'question': 'How many stages does this experiment have?',
#          'multiSelect': False,
#          'answers': ['1', '2', '3', '4'],
#          'correctAnswer': ['4'],
#          'answer': '4'},
#         {'id': 'q5',
#          'question': 'You can drag items in the response box to reorder them.',
#          'multiSelect': False,
#          'answers': ['True', 'False'],
#          'correctAnswer': ['True'],
#          'answer': 'True'},
#         {'id': 'q6',
#          'question': 'Are you allowed to take notes during the study?',
#          'multiSelect': False,
#          'answers': ['Yes', 'No'],
#          'correctAnswer': ['No'],
#          'answer': 'No'}]}],
#      'persist': {'attempts': 1}}],
#    'timestamps': [1777300431757]}},
#  'browserData': [{'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300124, '_nanoseconds': 111000000},
#    'event_data': {'width': 1771, 'height': 1138}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300124, '_nanoseconds': 133000000},
#    'event_data': {'width': 1773, 'height': 1143}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300124, '_nanoseconds': 149000000},
#    'event_data': {'width': 1775, 'height': 1147}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300124, '_nanoseconds': 166000000},
#    'event_data': {'width': 1776, 'height': 1148}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300124, '_nanoseconds': 192000000},
#    'event_data': {'width': 1777, 'height': 1149}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300124, '_nanoseconds': 209000000},
#    'event_data': {'width': 1778, 'height': 1151}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300124, '_nanoseconds': 225000000},
#    'event_data': {'width': 1780, 'height': 1153}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300124, '_nanoseconds': 241000000},
#    'event_data': {'width': 1780, 'height': 1154}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300124, '_nanoseconds': 258000000},
#    'event_data': {'width': 1780, 'height': 1155}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300124, '_nanoseconds': 299000000},
#    'event_data': {'width': 1780, 'height': 1156}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300124, '_nanoseconds': 376000000},
#    'event_data': {'width': 1780, 'height': 1155}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 394000000},
#    'event_data': {'width': 1790, 'height': 1157}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 415000000},
#    'event_data': {'width': 1797, 'height': 1158}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 432000000},
#    'event_data': {'width': 1806, 'height': 1160}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 449000000},
#    'event_data': {'width': 1812, 'height': 1160}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 466000000},
#    'event_data': {'width': 1818, 'height': 1160}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 482000000},
#    'event_data': {'width': 1824, 'height': 1161}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 499000000},
#    'event_data': {'width': 1833, 'height': 1162}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 516000000},
#    'event_data': {'width': 1836, 'height': 1162}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 575000000},
#    'event_data': {'width': 1838, 'height': 1162}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 616000000},
#    'event_data': {'width': 1838, 'height': 1163}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 666000000},
#    'event_data': {'width': 1838, 'height': 1164}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 682000000},
#    'event_data': {'width': 1838, 'height': 1166}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 699000000},
#    'event_data': {'width': 1838, 'height': 1168}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 758000000},
#    'event_data': {'width': 1838, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 878000000},
#    'event_data': {'width': 1835, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 899000000},
#    'event_data': {'width': 1832, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 916000000},
#    'event_data': {'width': 1829, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 932000000},
#    'event_data': {'width': 1827, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300125, '_nanoseconds': 949000000},
#    'event_data': {'width': 1826, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300126, '_nanoseconds': 8000000},
#    'event_data': {'width': 1823, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300126, '_nanoseconds': 25000000},
#    'event_data': {'width': 1819, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300126, '_nanoseconds': 41000000},
#    'event_data': {'width': 1811, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300126, '_nanoseconds': 58000000},
#    'event_data': {'width': 1807, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300126, '_nanoseconds': 75000000},
#    'event_data': {'width': 1805, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300126, '_nanoseconds': 244000000},
#    'event_data': {'width': 1802, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300126, '_nanoseconds': 264000000},
#    'event_data': {'width': 1801, 'height': 1169}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300131, '_nanoseconds': 512000000},
#    'event_data': {'width': 1795, 'height': 1163}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300131, '_nanoseconds': 532000000},
#    'event_data': {'width': 1794, 'height': 1162}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300131, '_nanoseconds': 564000000},
#    'event_data': {'width': 1793, 'height': 1161}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300131, '_nanoseconds': 582000000},
#    'event_data': {'width': 1792, 'height': 1160}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300131, '_nanoseconds': 599000000},
#    'event_data': {'width': 1789, 'height': 1158}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300131, '_nanoseconds': 615000000},
#    'event_data': {'width': 1786, 'height': 1156}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300131, '_nanoseconds': 632000000},
#    'event_data': {'width': 1784, 'height': 1155}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300131, '_nanoseconds': 649000000},
#    'event_data': {'width': 1783, 'height': 1154}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300131, '_nanoseconds': 666000000},
#    'event_data': {'width': 1781, 'height': 1154}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300131, '_nanoseconds': 682000000},
#    'event_data': {'width': 1780, 'height': 1153}},
#   {'event_type': 'blur',
#    'timestamp': {'_seconds': 1777300162, '_nanoseconds': 325000000}},
#   {'event_type': 'focus',
#    'timestamp': {'_seconds': 1777300206, '_nanoseconds': 851000000}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 544000000},
#    'event_data': {'width': 1797, 'height': 1160}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 565000000},
#    'event_data': {'width': 1804, 'height': 1163}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 581000000},
#    'event_data': {'width': 1808, 'height': 1164}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 597000000},
#    'event_data': {'width': 1810, 'height': 1165}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 615000000},
#    'event_data': {'width': 1813, 'height': 1166}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 632000000},
#    'event_data': {'width': 1815, 'height': 1167}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 648000000},
#    'event_data': {'width': 1819, 'height': 1168}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 665000000},
#    'event_data': {'width': 1823, 'height': 1170}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 682000000},
#    'event_data': {'width': 1826, 'height': 1171}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 698000000},
#    'event_data': {'width': 1829, 'height': 1172}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 715000000},
#    'event_data': {'width': 1831, 'height': 1173}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 732000000},
#    'event_data': {'width': 1834, 'height': 1174}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 748000000},
#    'event_data': {'width': 1836, 'height': 1175}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 765000000},
#    'event_data': {'width': 1839, 'height': 1177}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 782000000},
#    'event_data': {'width': 1842, 'height': 1179}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 797000000},
#    'event_data': {'width': 1845, 'height': 1180}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 815000000},
#    'event_data': {'width': 1847, 'height': 1181}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 832000000},
#    'event_data': {'width': 1849, 'height': 1181}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 848000000},
#    'event_data': {'width': 1851, 'height': 1182}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300223, '_nanoseconds': 865000000},
#    'event_data': {'width': 1852, 'height': 1182}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 44000000},
#    'event_data': {'width': 1853, 'height': 1182}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 65000000},
#    'event_data': {'width': 1854, 'height': 1183}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 82000000},
#    'event_data': {'width': 1856, 'height': 1184}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 98000000},
#    'event_data': {'width': 1858, 'height': 1185}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 115000000},
#    'event_data': {'width': 1859, 'height': 1185}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 132000000},
#    'event_data': {'width': 1860, 'height': 1186}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 147000000},
#    'event_data': {'width': 1861, 'height': 1186}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 164000000},
#    'event_data': {'width': 1862, 'height': 1187}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 182000000},
#    'event_data': {'width': 1864, 'height': 1188}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 198000000},
#    'event_data': {'width': 1865, 'height': 1188}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 215000000},
#    'event_data': {'width': 1865, 'height': 1189}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 232000000},
#    'event_data': {'width': 1867, 'height': 1189}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 248000000},
#    'event_data': {'width': 1868, 'height': 1189}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300224, '_nanoseconds': 298000000},
#    'event_data': {'width': 1868, 'height': 1190}},
#   {'event_type': 'blur',
#    'timestamp': {'_seconds': 1777300270, '_nanoseconds': 56000000}},
#   {'event_type': 'focus',
#    'timestamp': {'_seconds': 1777300357, '_nanoseconds': 289000000}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300456, '_nanoseconds': 647000000},
#    'event_data': {'width': 1878, 'height': 1191}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300456, '_nanoseconds': 667000000},
#    'event_data': {'width': 1882, 'height': 1192}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300456, '_nanoseconds': 684000000},
#    'event_data': {'width': 1884, 'height': 1193}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300456, '_nanoseconds': 701000000},
#    'event_data': {'width': 1887, 'height': 1193}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300456, '_nanoseconds': 717000000},
#    'event_data': {'width': 1889, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300456, '_nanoseconds': 734000000},
#    'event_data': {'width': 1891, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300456, '_nanoseconds': 751000000},
#    'event_data': {'width': 1893, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300456, '_nanoseconds': 767000000},
#    'event_data': {'width': 1894, 'height': 1195}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300457, '_nanoseconds': 29000000},
#    'event_data': {'width': 1893, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 697000000},
#    'event_data': {'width': 1882, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 717000000},
#    'event_data': {'width': 1878, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 736000000},
#    'event_data': {'width': 1874, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 751000000},
#    'event_data': {'width': 1871, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 768000000},
#    'event_data': {'width': 1870, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 785000000},
#    'event_data': {'width': 1868, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 801000000},
#    'event_data': {'width': 1866, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 818000000},
#    'event_data': {'width': 1863, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 834000000},
#    'event_data': {'width': 1860, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 850000000},
#    'event_data': {'width': 1856, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 867000000},
#    'event_data': {'width': 1852, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 926000000},
#    'event_data': {'width': 1851, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300463, '_nanoseconds': 948000000},
#    'event_data': {'width': 1850, 'height': 1194}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 26000000},
#    'event_data': {'width': 1850, 'height': 1153}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 43000000},
#    'event_data': {'width': 1850, 'height': 1151}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 59000000},
#    'event_data': {'width': 1850, 'height': 1149}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 76000000},
#    'event_data': {'width': 1850, 'height': 1148}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 92000000},
#    'event_data': {'width': 1850, 'height': 1145}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 109000000},
#    'event_data': {'width': 1850, 'height': 1143}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 126000000},
#    'event_data': {'width': 1850, 'height': 1142}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 166000000},
#    'event_data': {'width': 1850, 'height': 1141}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 183000000},
#    'event_data': {'width': 1850, 'height': 1140}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 199000000},
#    'event_data': {'width': 1850, 'height': 1138}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 217000000},
#    'event_data': {'width': 1850, 'height': 1137}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 234000000},
#    'event_data': {'width': 1850, 'height': 1136}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 309000000},
#    'event_data': {'width': 1850, 'height': 1139}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 326000000},
#    'event_data': {'width': 1848, 'height': 1144}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 343000000},
#    'event_data': {'width': 1847, 'height': 1152}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 359000000},
#    'event_data': {'width': 1846, 'height': 1163}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 376000000},
#    'event_data': {'width': 1846, 'height': 1172}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 392000000},
#    'event_data': {'width': 1846, 'height': 1176}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 409000000},
#    'event_data': {'width': 1847, 'height': 1178}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 426000000},
#    'event_data': {'width': 1847, 'height': 1179}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 442000000},
#    'event_data': {'width': 1847, 'height': 1180}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300464, '_nanoseconds': 483000000},
#    'event_data': {'width': 1847, 'height': 1181}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300471, '_nanoseconds': 697000000},
#    'event_data': {'width': 1836, 'height': 1173}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300471, '_nanoseconds': 718000000},
#    'event_data': {'width': 1830, 'height': 1170}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300471, '_nanoseconds': 734000000},
#    'event_data': {'width': 1820, 'height': 1166}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300471, '_nanoseconds': 751000000},
#    'event_data': {'width': 1810, 'height': 1162}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300471, '_nanoseconds': 767000000},
#    'event_data': {'width': 1807, 'height': 1161}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300471, '_nanoseconds': 784000000},
#    'event_data': {'width': 1806, 'height': 1161}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300471, '_nanoseconds': 801000000},
#    'event_data': {'width': 1805, 'height': 1160}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300471, '_nanoseconds': 817000000},
#    'event_data': {'width': 1801, 'height': 1160}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300471, '_nanoseconds': 834000000},
#    'event_data': {'width': 1797, 'height': 1159}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300471, '_nanoseconds': 851000000},
#    'event_data': {'width': 1797, 'height': 1158}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300472, '_nanoseconds': 729000000},
#    'event_data': {'width': 1797, 'height': 1159}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300472, '_nanoseconds': 751000000},
#    'event_data': {'width': 1797, 'height': 1161}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300472, '_nanoseconds': 767000000},
#    'event_data': {'width': 1797, 'height': 1164}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300473, '_nanoseconds': 79000000},
#    'event_data': {'width': 1799, 'height': 1164}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300473, '_nanoseconds': 100000000},
#    'event_data': {'width': 1804, 'height': 1164}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300473, '_nanoseconds': 117000000},
#    'event_data': {'width': 1807, 'height': 1165}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300473, '_nanoseconds': 134000000},
#    'event_data': {'width': 1808, 'height': 1165}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300473, '_nanoseconds': 395000000},
#    'event_data': {'width': 1808, 'height': 1164}},
#   {'event_type': 'blur',
#    'timestamp': {'_seconds': 1777300704, '_nanoseconds': 398000000}},
#   {'event_type': 'focus',
#    'timestamp': {'_seconds': 1777300775, '_nanoseconds': 823000000}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 514000000},
#    'event_data': {'width': 1830, 'height': 1157}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 534000000},
#    'event_data': {'width': 1844, 'height': 1156}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 552000000},
#    'event_data': {'width': 1857, 'height': 1156}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 569000000},
#    'event_data': {'width': 1866, 'height': 1155}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 585000000},
#    'event_data': {'width': 1873, 'height': 1155}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 602000000},
#    'event_data': {'width': 1875, 'height': 1155}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 619000000},
#    'event_data': {'width': 1877, 'height': 1156}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 635000000},
#    'event_data': {'width': 1880, 'height': 1156}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 652000000},
#    'event_data': {'width': 1881, 'height': 1156}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 669000000},
#    'event_data': {'width': 1882, 'height': 1156}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 685000000},
#    'event_data': {'width': 1884, 'height': 1156}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300791, '_nanoseconds': 777000000},
#    'event_data': {'width': 1885, 'height': 1156}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300832, '_nanoseconds': 769000000},
#    'event_data': {'width': 1876, 'height': 1147}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300832, '_nanoseconds': 785000000},
#    'event_data': {'width': 1874, 'height': 1145}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300832, '_nanoseconds': 801000000},
#    'event_data': {'width': 1873, 'height': 1143}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300832, '_nanoseconds': 818000000},
#    'event_data': {'width': 1872, 'height': 1142}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300832, '_nanoseconds': 835000000},
#    'event_data': {'width': 1871, 'height': 1141}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300832, '_nanoseconds': 851000000},
#    'event_data': {'width': 1869, 'height': 1139}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300832, '_nanoseconds': 868000000},
#    'event_data': {'width': 1868, 'height': 1138}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300832, '_nanoseconds': 885000000},
#    'event_data': {'width': 1867, 'height': 1136}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777300833, '_nanoseconds': 63000000},
#    'event_data': {'width': 1866, 'height': 1136}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 465000000},
#    'event_data': {'width': 1848, 'height': 1132}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 485000000},
#    'event_data': {'width': 1839, 'height': 1130}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 502000000},
#    'event_data': {'width': 1831, 'height': 1128}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 518000000},
#    'event_data': {'width': 1818, 'height': 1126}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 535000000},
#    'event_data': {'width': 1806, 'height': 1125}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 552000000},
#    'event_data': {'width': 1796, 'height': 1124}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 568000000},
#    'event_data': {'width': 1794, 'height': 1124}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 585000000},
#    'event_data': {'width': 1793, 'height': 1124}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 815000000},
#    'event_data': {'width': 1795, 'height': 1130}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 835000000},
#    'event_data': {'width': 1800, 'height': 1137}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 852000000},
#    'event_data': {'width': 1804, 'height': 1140}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 868000000},
#    'event_data': {'width': 1805, 'height': 1141}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 928000000},
#    'event_data': {'width': 1806, 'height': 1141}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 950000000},
#    'event_data': {'width': 1812, 'height': 1141}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 968000000},
#    'event_data': {'width': 1817, 'height': 1141}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301004, '_nanoseconds': 985000000},
#    'event_data': {'width': 1823, 'height': 1140}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301005, '_nanoseconds': 2000000},
#    'event_data': {'width': 1828, 'height': 1140}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301005, '_nanoseconds': 18000000},
#    'event_data': {'width': 1835, 'height': 1139}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301005, '_nanoseconds': 35000000},
#    'event_data': {'width': 1840, 'height': 1138}},
#   {'event_type': 'resize',
#    'timestamp': {'_seconds': 1777301005, '_nanoseconds': 52000000},
#    'event_data': {'width': 1841, 'height': 1138}},
#   {'event_type': 'blur',
#    'timestamp': {'_seconds': 1777301008, '_nanoseconds': 471000000}},
#   {'event_type': 'focus',
#    'timestamp': {'_seconds': 1777301048, '_nanoseconds': 899000000}}],
#  'pageData_exp': {'visit_0': {'data': [{'phase': 'response_train',
#      'abs_input': 'p2 m2 p3',
#      'raw_input': 'gazzer wif dax',
#      'abs_target': 'c2 c3 c2',
#      'raw_target': '#00b0b3 #0000ff #00b0b3',
#      'abs_response': 'c2 c3 c2',
#      'raw_response': 'color:#00b0b3; color:#0000ff; color:#00b0b3;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 0,
#      'rt': 7774},
#     {'phase': 'response_train',
#      'abs_input': 'p3 m2 p1',
#      'raw_input': 'dax wif kiki',
#      'abs_target': 'c3 c1 c3',
#      'raw_target': '#0000ff #b7b600 #0000ff',
#      'abs_response': 'c3 c1 c3',
#      'raw_response': 'color:#0000ff; color:#b7b600; color:#0000ff;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 0,
#      'rt': 13302},
#     {'phase': 'test',
#      'abs_input': 'p1 m2 p4',
#      'raw_input': 'kiki wif lug',
#      'abs_target': 'c1 c4 c1',
#      'raw_target': '#b7b600 #33cc33 #b7b600',
#      'abs_response': 'c1 c4 c1',
#      'raw_response': 'color:#b7b600; color:#33cc33; color:#b7b600;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 0,
#      'rt': 9315},
#     {'phase': 'test',
#      'abs_input': 'p4 m2 p2',
#      'raw_input': 'lug wif gazzer',
#      'abs_target': 'c4 c2 c4',
#      'raw_target': '#33cc33 #00b0b3 #33cc33',
#      'abs_response': 'c4 c2 c4',
#      'raw_response': 'color:#33cc33; color:#00b0b3; color:#33cc33;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 0,
#      'rt': 14775},
#     {'phase': 'test',
#      'abs_input': 'p2 m2 p3',
#      'raw_input': 'gazzer wif dax',
#      'abs_target': 'c2 c3 c2',
#      'raw_target': '#00b0b3 #0000ff #00b0b3',
#      'abs_response': 'c2 c3 c2',
#      'raw_response': 'color:#00b0b3; color:#0000ff; color:#00b0b3;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 0,
#      'rt': 15269},
#     {'phase': 'response_train',
#      'abs_input': 'p2 m3 p3',
#      'raw_input': 'gazzer blicket dax',
#      'abs_target': 'c3 c2',
#      'raw_target': '#0000ff #00b0b3',
#      'abs_response': 'c3 c2',
#      'raw_response': 'color:#0000ff; color:#00b0b3;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 1,
#      'rt': 20757},
#     {'phase': 'response_train',
#      'abs_input': 'p1 m3 p2',
#      'raw_input': 'kiki blicket gazzer',
#      'abs_target': 'c2 c1',
#      'raw_target': '#00b0b3 #b7b600',
#      'abs_response': 'c2 c1',
#      'raw_response': 'color:#00b0b3; color:#b7b600;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 1,
#      'rt': 4875},
#     {'phase': 'test',
#      'abs_input': 'p2 m3 p3',
#      'raw_input': 'gazzer blicket dax',
#      'abs_target': 'c3 c2',
#      'raw_target': '#0000ff #00b0b3',
#      'abs_response': 'c3 c2',
#      'raw_response': 'color:#0000ff; color:#00b0b3;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 1,
#      'rt': 9603},
#     {'phase': 'test',
#      'abs_input': 'p3 m3 p4',
#      'raw_input': 'dax blicket lug',
#      'abs_target': 'c4 c3',
#      'raw_target': '#33cc33 #0000ff',
#      'abs_response': 'c4 c3',
#      'raw_response': 'color:#33cc33; color:#0000ff;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 1,
#      'rt': 8081},
#     {'phase': 'test',
#      'abs_input': 'p4 m3 p1',
#      'raw_input': 'lug blicket kiki',
#      'abs_target': 'c1 c4',
#      'raw_target': '#b7b600 #33cc33',
#      'abs_response': 'c1 c4',
#      'raw_response': 'color:#b7b600; color:#33cc33;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 1,
#      'rt': 16815},
#     {'phase': 'response_train',
#      'abs_input': 'p2 m1',
#      'raw_input': 'gazzer tufa',
#      'abs_target': 'c2 c2 c2',
#      'raw_target': '#00b0b3 #00b0b3 #00b0b3',
#      'abs_response': 'c2 c2 c2',
#      'raw_response': 'color:#00b0b3; color:#00b0b3; color:#00b0b3;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 2,
#      'rt': 8294},
#     {'phase': 'response_train',
#      'abs_input': 'p1 m1',
#      'raw_input': 'kiki tufa',
#      'abs_target': 'c1 c1 c1',
#      'raw_target': '#b7b600 #b7b600 #b7b600',
#      'abs_response': 'c1 c1 c1',
#      'raw_response': 'color:#b7b600; color:#b7b600; color:#b7b600;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 2,
#      'rt': 3870},
#     {'phase': 'test',
#      'abs_input': 'p2 m1',
#      'raw_input': 'gazzer tufa',
#      'abs_target': 'c2 c2 c2',
#      'raw_target': '#00b0b3 #00b0b3 #00b0b3',
#      'abs_response': 'c2 c2 c2',
#      'raw_response': 'color:#00b0b3; color:#00b0b3; color:#00b0b3;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 2,
#      'rt': 4994},
#     {'phase': 'test',
#      'abs_input': 'p4 m1',
#      'raw_input': 'lug tufa',
#      'abs_target': 'c4 c4 c4',
#      'raw_target': '#33cc33 #33cc33 #33cc33',
#      'abs_response': 'c4 c4 c4',
#      'raw_response': 'color:#33cc33; color:#33cc33; color:#33cc33;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 2,
#      'rt': 3119},
#     {'phase': 'response_train',
#      'abs_input': 'p3 m2 p1 m3 p2',
#      'raw_input': 'dax wif kiki blicket gazzer',
#      'abs_target': 'c2 c3 c1 c3',
#      'raw_target': '#00b0b3 #0000ff #b7b600 #0000ff',
#      'abs_response': 'c2 c3 c1 c3',
#      'raw_response': 'color:#00b0b3; color:#0000ff; color:#b7b600; color:#0000ff;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 3,
#      'rt': 75888},
#     {'phase': 'response_train',
#      'abs_input': 'p2 m3 p3',
#      'raw_input': 'gazzer blicket dax',
#      'abs_target': 'c3 c2',
#      'raw_target': '#0000ff #00b0b3',
#      'abs_response': 'c3 c2',
#      'raw_response': 'color:#0000ff; color:#00b0b3;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 3,
#      'rt': 10468},
#     {'phase': 'response_train',
#      'abs_input': 'p2 m1 m3 p3',
#      'raw_input': 'gazzer tufa blicket dax',
#      'abs_target': 'c3 c2 c2 c2',
#      'raw_target': '#0000ff #00b0b3 #00b0b3 #00b0b3',
#      'abs_response': 'c3 c2 c2 c2',
#      'raw_response': 'color:#0000ff; color:#00b0b3; color:#00b0b3; color:#00b0b3;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 3,
#      'rt': 20158},
#     {'phase': 'response_train',
#      'abs_input': 'p3 m3 p1 m2 p2',
#      'raw_input': 'dax blicket kiki wif gazzer',
#      'abs_target': 'c1 c2 c1 c3',
#      'raw_target': '#b7b600 #00b0b3 #b7b600 #0000ff',
#      'abs_response': 'c1 c2 c1 c3',
#      'raw_response': 'color:#b7b600; color:#00b0b3; color:#b7b600; color:#0000ff;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 3,
#      'rt': 25016},
#     {'phase': 'response_train',
#      'abs_input': 'p1 m1',
#      'raw_input': 'kiki tufa',
#      'abs_target': 'c1 c1 c1',
#      'raw_target': '#b7b600 #b7b600 #b7b600',
#      'abs_response': 'c1 c1 c1',
#      'raw_response': 'color:#b7b600; color:#b7b600; color:#b7b600;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 3,
#      'rt': 4769},
#     {'phase': 'response_train',
#      'abs_input': 'p2 m2 p3',
#      'raw_input': 'gazzer wif dax',
#      'abs_target': 'c2 c3 c2',
#      'raw_target': '#00b0b3 #0000ff #00b0b3',
#      'abs_response': 'c2 c3 c2',
#      'raw_response': 'color:#00b0b3; color:#0000ff; color:#00b0b3;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 3,
#      'rt': 12611},
#     {'phase': 'response_train',
#      'abs_input': 'p2 m1',
#      'raw_input': 'gazzer tufa',
#      'abs_target': 'c2 c2 c2',
#      'raw_target': '#00b0b3 #00b0b3 #00b0b3',
#      'abs_response': 'c2 c2 c2',
#      'raw_response': 'color:#00b0b3; color:#00b0b3; color:#00b0b3;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 3,
#      'rt': 5552},
#     {'phase': 'response_train',
#      'abs_input': 'p2 m3 p3 m1',
#      'raw_input': 'gazzer blicket dax tufa',
#      'abs_target': 'c3 c3 c3 c2',
#      'raw_target': '#0000ff #0000ff #0000ff #00b0b3',
#      'abs_response': 'c3 c3 c3 c2',
#      'raw_response': 'color:#0000ff; color:#0000ff; color:#0000ff; color:#00b0b3;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 3,
#      'rt': 14595},
#     {'phase': 'response_train',
#      'abs_input': 'p3 m2 p1',
#      'raw_input': 'dax wif kiki',
#      'abs_target': 'c3 c1 c3',
#      'raw_target': '#0000ff #b7b600 #0000ff',
#      'abs_response': 'c3 c1 c3',
#      'raw_response': 'color:#0000ff; color:#b7b600; color:#0000ff;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 3,
#      'rt': 19303},
#     {'phase': 'response_train',
#      'abs_input': 'p1 m3 p2',
#      'raw_input': 'kiki blicket gazzer',
#      'abs_target': 'c2 c1',
#      'raw_target': '#00b0b3 #b7b600',
#      'abs_response': 'c2 c1',
#      'raw_response': 'color:#00b0b3; color:#b7b600;',
#      'correct': True,
#      'cycle': 1,
#      'learning_stage': 3,
#      'rt': 10242},
#     {'phase': 'test',
#      'abs_input': 'p4 m2 p3 m3 p1 m1',
#      'raw_input': 'lug wif dax blicket kiki tufa',
#      'abs_target': 'c1 c1 c1 c4 c3 c4',
#      'raw_target': '#b7b600 #b7b600 #b7b600 #33cc33 #0000ff #33cc33',
#      'abs_response': 'c1 c1 c1 c3 c4 c3',
#      'raw_response': 'color:#b7b600; color:#b7b600; color:#b7b600; color:#0000ff; color:#33cc33; color:#0000ff;',
#      'correct': False,
#      'cycle': -1,
#      'learning_stage': 3,
#      'rt': 118579},
#     {'phase': 'test',
#      'abs_input': 'p3 m3 p4 m1',
#      'raw_input': 'dax blicket lug tufa',
#      'abs_target': 'c4 c4 c4 c3',
#      'raw_target': '#33cc33 #33cc33 #33cc33 #0000ff',
#      'abs_response': 'c4 c4 c4 c3',
#      'raw_response': 'color:#33cc33; color:#33cc33; color:#33cc33; color:#0000ff;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 3,
#      'rt': 9966},
#     {'phase': 'test',
#      'abs_input': 'p4 m2 p4 m3 p4 m1',
#      'raw_input': 'lug wif lug blicket lug tufa',
#      'abs_target': 'c4 c4 c4 c4 c4 c4',
#      'raw_target': '#33cc33 #33cc33 #33cc33 #33cc33 #33cc33 #33cc33',
#      'abs_response': 'c4 c4 c4 c4 c4 c4',
#      'raw_response': 'color:#33cc33; color:#33cc33; color:#33cc33; color:#33cc33; color:#33cc33; color:#33cc33;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 3,
#      'rt': 12771},
#     {'phase': 'test',
#      'abs_input': 'p4 m1 m3 p2',
#      'raw_input': 'lug tufa blicket gazzer',
#      'abs_target': 'c2 c4 c4 c4',
#      'raw_target': '#00b0b3 #33cc33 #33cc33 #33cc33',
#      'abs_response': 'c2 c4 c4 c4',
#      'raw_response': 'color:#00b0b3; color:#33cc33; color:#33cc33; color:#33cc33;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 3,
#      'rt': 30601},
#     {'phase': 'test',
#      'abs_input': 'p2 m3 p3 m2 p4',
#      'raw_input': 'gazzer blicket dax wif lug',
#      'abs_target': 'c3 c4 c3 c2',
#      'raw_target': '#0000ff #33cc33 #0000ff #00b0b3',
#      'abs_response': 'c3 c4 c3 c2',
#      'raw_response': 'color:#0000ff; color:#33cc33; color:#0000ff; color:#00b0b3;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 3,
#      'rt': 49470},
#     {'phase': 'test',
#      'abs_input': 'p2 m1 m3 p3',
#      'raw_input': 'gazzer tufa blicket dax',
#      'abs_target': 'c3 c2 c2 c2',
#      'raw_target': '#0000ff #00b0b3 #00b0b3 #00b0b3',
#      'abs_response': 'c3 c2 c2 c2',
#      'raw_response': 'color:#0000ff; color:#00b0b3; color:#00b0b3; color:#00b0b3;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 3,
#      'rt': 34240},
#     {'phase': 'test',
#      'abs_input': 'p3 m3 p1 m2 p2',
#      'raw_input': 'dax blicket kiki wif gazzer',
#      'abs_target': 'c1 c2 c1 c3',
#      'raw_target': '#b7b600 #00b0b3 #b7b600 #0000ff',
#      'abs_response': 'c1 c2 c1 c3',
#      'raw_response': 'color:#b7b600; color:#00b0b3; color:#b7b600; color:#0000ff;',
#      'correct': True,
#      'cycle': -1,
#      'learning_stage': 3,
#      'rt': 14417}],
#    'timestamps': [1777300533340,
#     1777300547242,
#     1777300569486,
#     1777300584262,
#     1777300599531,
#     1777300622107,
#     1777300627777,
#     1777300641251,
#     1777300649334,
#     1777300666149,
#     1777300676078,
#     1777300680909,
#     1777300687510,
#     1777300690629,
#     1777300852946,
#     1777300864480,
#     1777300885196,
#     1777300910711,
#     1777300916020,
#     1777300929220,
#     1777300935884,
#     1777300950942,
#     1777300970710,
#     1777300981632,
#     1777301102311,
#     1777301112278,
#     1777301125049,
#     1777301155651,
#     1777301205121,
#     1777301239362,
#     1777301253779]}},
#  'pageData_postquestionnaire': {'visit_0': {'data': [{'survey_txt_strategy': 'I did my best',
#      'external_aid': 'No',
#      'clarity': '1',
#      'screensize': 'Yes',
#      'survey_txt_trouble': 'None'}],
#    'timestamps': [1777301275501]}},
#  'routeOrder': [{'route': 'welcome_referred',
#    'timestamp': 1777300103775,
#    'timeDelta': 1938},
#   {'route': 'consent', 'timestamp': 1777300105713, 'timeDelta': 1547},
#   {'route': 'windowsizer', 'timestamp': 1777300107260, 'timeDelta': 2369},
#   {'route': 'instructions', 'timestamp': 1777300109629, 'timeDelta': 293628},
#   {'route': 'quiz', 'timestamp': 1777300403257, 'timeDelta': 29566},
#   {'route': 'exp', 'timestamp': 1777300432823, 'timeDelta': 820980},
#   {'route': 'postquestionnaire',
#    'timestamp': 1777301253803,
#    'timeDelta': 21729},
#   {'route': 'thanks', 'timestamp': 1777301275532, 'timeDelta': None}],
#  'lastUpdated': {'_seconds': 1777301279, '_nanoseconds': 618000000},
#  'endtime': {'_seconds': 1777301275, '_nanoseconds': 532000000},
#  'done': True,
#  'endtimeLocal': '2026-04-27T10:47:55.532-04:00',
#  'smile_config': {'firebaseConfig': {}}}

# %%
mypart.keys()
print(mypart.keys())
mypart['pageData_exp']['visit_0']['data'][-2]
# Out:
# dict_keys(['appStartTime', 'seedID', 'firebaseAnonAuthID', 'trialNum', 'consented', 'starttime', 'starttimeLocal', 'userTimezone', 'userTimezoneOffset', 'panda_id', 'recruitmentService', 'withdrawn', 'conditions', 'randomizedRoutes', 'smileConfig', 'studyData', 'firebaseDocID', 'verifiedVisibility', 'pageData_quiz', 'browserData', 'pageData_exp', 'pageData_postquestionnaire', 'routeOrder', 'lastUpdated', 'endtime', 'done', 'endtimeLocal', 'smile_config'])
# {'phase': 'test',
#  'abs_input': 'p2 m1 m3 p3',
#  'raw_input': 'gazzer tufa blicket dax',
#  'abs_target': 'c3 c2 c2 c2',
#  'raw_target': '#0000ff #00b0b3 #00b0b3 #00b0b3',
#  'abs_response': 'c3 c2 c2 c2',
#  'raw_response': 'color:#0000ff; color:#00b0b3; color:#00b0b3; color:#00b0b3;',
#  'correct': True,
#  'cycle': -1,
#  'learning_stage': 3,
#  'rt': 34240}
